# %%
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt
import cartopy as cr
import cartopy.feature as cf
import cartopy.crs as ccrs

# %%
clim_skt = xr.open_dataset("./skt.sfc.ymonmean.nc")
clim_mslp = xr.open_dataset("./mslp.ymonmean.nc")

# %%
clim_mslp = clim_mslp.mslp
clim_skt = clim_skt.skt

# %%
clim_skt_land = clim_skt.sel(lat=20,lon=80,method='nearest')
clim_mslp_land = clim_mslp.sel(lat=20,lon=80,method='nearest')
# Out:
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(

# %%
fig, ax1 = plt.subplots(figsize=(8,5))
ax2 = ax1.twinx()
ax1.plot(clim_skt_land-273.5,'b.-',label='Skin Temp')
ax2.plot(clim_mslp_land/100,'r.-',label='MSLP')

ax1.set_xlabel('Time')
ax1.set_ylabel('Skin Temp (degC)')
ax2.set_ylabel('MSLP (hPa)')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Time Series of Skin Temp and MSLP at Land (20N,80E)')
plt.savefig("./task3_plots/Time Series of Skin Temp and MSLP at Land (20N,80E)")

# %%
clim_skt_ocean = clim_skt.sel(lat=-20,lon=80,method='nearest')
clim_mslp_ocean = clim_mslp.sel(lat=-20,lon=80,method='nearest')
# Out:
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(
# c:\Users\Akshit Nanda\anaconda3\lib\site-packages\xarray\core\indexes.py:234: FutureWarning: Passing method to Float64Index.get_loc is deprecated and will raise in a future version. Use index.get_indexer([item], method=...) instead.
#   indexer = self.index.get_loc(

# %%
fig, ax1 = plt.subplots(figsize=(8,5))
ax2 = ax1.twinx()
ax1.plot(clim_skt_ocean-273.5,'b.-',label='Skin Temp')
ax2.plot(clim_mslp_ocean/100,'r.-',label='MSLP')

ax1.set_xlabel('Time')
ax1.set_ylabel('Skin Temp (degC)')
ax2.set_ylabel('MSLP (hPa)')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.title('Time Series of Skin Temp and MSLP at Ocean (20N,80E)')
plt.savefig("./task3_plots/Time Series of Skin Temp and MSLP at Ocean (20N,80E)")
