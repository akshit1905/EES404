# %%
import numpy as np
import matplotlib.pyplot as plt

import xarray as xr

# %%
file = xr.open_dataset('../task-4/cru_ts4.06.1901.2021.3_11.pre_tmp.mean.corr.dat.nc')

# %%
lon = file.lon; lat = file.lat

# %%
plt.figure(figsize=(8,5))
plt.plot(file['time'],file['pre'][:,0,0],'-o')
plt.title('Time Series Correlation Between Precipitation and mean Temperature')
plt.minorticks_on()
plt.xlabel('year')
plt.savefig('../task-4/plots/fldcorr_pre_tmp.png')
